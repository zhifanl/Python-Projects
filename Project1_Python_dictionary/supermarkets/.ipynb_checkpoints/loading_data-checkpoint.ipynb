# %%
import os
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas
df1=pandas.read_csv("supermarkets.csv")

df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt",sep=",")
df5
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
df6=pandas.read_csv("supermarkets-semi-colons.txt",sep=";",header=None)
df6.columns=["ID","Address","City","ZIP","Country","Name","Employees"]
df9=df6.set_index("ID")
df9
# Out:
#             Address           City               ZIP  Country          Name  \
# ID
# ID          Address           City             State  Country          Name
# 1      3666 21st St  San Francisco          CA 94114      USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA    Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index("ID")
df6.loc["Madeira":"Sanchez","ID":"ZIP"]
# Out:
#              ID           City               ZIP
# Name
# Madeira       1  San Francisco          CA 94114
# Bready Shop   2  San Francisco          CA 94119
#  Super River  3  San Francisco  California 94114
# Ben's Shop    4  San Francisco          CA 94114
# Sanchez       5  San Francisco        California

# %%
df6
#df6.iloc[1:3,1:3]
# Out:
#               ID           City               ZIP  Country          Name  \
# Name
# Name          ID           City             State  Country          Name
# Madeira        1  San Francisco          CA 94114      USA       Madeira
# Bready Shop    2  San Francisco          CA 94119      USA   Bready Shop
#  Super River   3  San Francisco  California 94114      USA   Super River
# Ben's Shop     4  San Francisco          CA 94114      USA    Ben's Shop
# Sanchez        5  San Francisco        California      USA       Sanchez
# Richvalley     6  San Francisco          CA 94114      USA    Richvalley
#
#               Employees
# Name
# Name          Employees
# Madeira               8
# Bready Shop          15
#  Super River         25
# Ben's Shop           10
# Sanchez              12
# Richvalley           20

# %%
df6.iloc[:,4:6]
# Out:
#                       Name  Employees
# Name
# Name                  Name  Employees
# Madeira            Madeira          8
# Bready Shop    Bready Shop         15
#  Super River   Super River         25
# Ben's Shop      Ben's Shop         10
# Sanchez            Sanchez         12
# Richvalley      Richvalley         20

# %%
df6
# Out:
#               ID           City               ZIP  Country          Name  \
# Name
# Name          ID           City             State  Country          Name
# Madeira        1  San Francisco          CA 94114      USA       Madeira
# Bready Shop    2  San Francisco          CA 94119      USA   Bready Shop
#  Super River   3  San Francisco  California 94114      USA   Super River
# Ben's Shop     4  San Francisco          CA 94114      USA    Ben's Shop
# Sanchez        5  San Francisco        California      USA       Sanchez
# Richvalley     6  San Francisco          CA 94114      USA    Richvalley
#
#               Employees
# Name
# Name          Employees
# Madeira               8
# Bready Shop          15
#  Super River         25
# Ben's Shop           10
# Sanchez              12
# Richvalley           20

# %%
from geopy import ArcGIS
arc=ArcGIS()
n=arc.geocode("320 300 Edgedale drive NW Calgary")
print(n)
n.latitude
n.longitude
# Out:
# 300 Edgedale Dr NW, Calgary, Alberta, T3A 4A6
# -114.15524999338912

# %%
import pandas
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+","+df["City"]+","+df["State"]+","+df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(arc.geocode)
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0].latitude
# Out:
# 37.756648011392286

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x !=None else None)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x !=None else None)

df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
